# %% [markdown]
# ## At first install pixellib library

# %%
! pip install pixellib
# Out:
# Collecting pixellib
#   Downloading https://files.pythonhosted.org/packages/55/d2/caf39a35ae14510f2f8b4d52f6673f791218400e58b39698b5bbb637dc0b/pixellib-0.1.0-py3-none-any.whl
# Installing collected packages: pixellib
# Successfully installed pixellib-0.1.0

# %% [markdown]
# ## Download mask rcnn coco weights

# %%
# !wget --quiet https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5

# %% [markdown]
# ## Upload Your Input Images

# %%
from google.colab import files # Use to load data on Google Colab
uploaded = files.upload() # Use to load data on Google Colab
# Out:
#      <input type="file" id="files-45883d21-58da-4e25-b5c0-3615bf6b6164" name="files[]" multiple disabled />
#      <output id="result-45883d21-58da-4e25-b5c0-3615bf6b6164">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving airport.jpg to airport.jpg
# Saving sample_image.jpg to sample_image.jpg

# %% [markdown]
# ## Show Input Image

# %%
plt.rcParams["figure.figsize"] = (50,10)
image=cv2.imread("airport.jpg")
plt.imshow(image)

# %% [markdown]
# ## Import Libraries and Use pixellib built in function to create object and load model

# %%
import pixellib
from pixellib.instance import instance_segmentation
import matplotlib.pyplot as plt
import cv2
segment_image = instance_segmentation()
segment_image.load_model("mask_rcnn_coco.h5")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# Use segmentImage function for image segmentation, pass input image and output image name, and make show_bboxes parameter True for bounding box object detection

# %% [markdown]
# ## Image Segementation and Object Detection

# %%
segment_image.segmentImage("airport.jpg", output_image_name = "image_new.jpeg",show_bboxes = True)
image=cv2.imread("image_new.jpeg")
plt.rcParams["figure.figsize"] = (50,10)
plt.imshow(image)
# Out:
# Processing image....
# Processed Image saved successfully in your current working directory.

# %% [markdown]
# ## Show Input Image

# %%
image=cv2.imread("sample_image.jpg")
plt.imshow(image)

# %% [markdown]
# ## Image Segementation and Object Detection

# %%
segment_image.segmentImage("sample_image.jpg", output_image_name = "sample_image_new.jpeg",show_bboxes = True)
image=cv2.imread("sample_image_new.jpeg")
plt.imshow(image)
# Out:
# Processing image....
# Processed Image saved successfully in your current working directory.

# %% [markdown]
# For More Tutorials Visit [My Blog](https://www.shawonruet.com)
